# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv(
    "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/car_insurance_pricing_features.csv"
)

df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  policy_year  \
# 0          41         16600             0        16600.0  ...         2023
# 1          23         14100             0        14100.0  ...         2023
# 2          53         19200             0        19200.0  ...         2024
# 3          36         13300             0        13300.0  ...         2024
# 4          57         13100             5        12445.0  ...         2024
#
#    underwriting_margin  premium_per_vehicle_age  discount_applied  \
# 0          8924.196385              1276.923077                 0
# 1          2989.708434              1762.500000                 0
# 2          7489.870605              3840.000000                 0
# 3          7497.973768              1108.333333                 0
# 4          6618.130912              4148.333333                 1
#
#    discount_bucket avg_vehicle_premium  premium_deviation_pct  \
# 0      No Discount        16035.203145               3.522231
# 1      No Discount        13138.717949               7.316407
# 2      No Discount        20650.765125              -7.025237
# 3      No Discount        13138.717949               1.227533
# 4              Low        13138.717949              -5.279952
#
#    risk_adjusted_discount  pricing_status effective_price_index
# 0                0.000000      Profitable              1.035222
# 1                0.000000      Profitable              1.073164
# 2                0.000000      Profitable              0.929748
# 3                0.000000      Profitable              1.012275
# 4                1.666667      Profitable              0.947200
#
# [5 rows x 21 columns]

# %%
discount_impact = (
    df.groupby("discount_bucket")["premium_deviation_pct"]
      .mean()
      .reset_index()
      .sort_values("premium_deviation_pct")
)

discount_impact
# Out:
#   discount_bucket  premium_deviation_pct
# 0            High             -11.011101
# 2          Medium              -5.940255
# 1             Low              -0.014100
# 3     No Discount               5.364792

# %%
margin_by_discount = (
    df.groupby("discount_bucket")["underwriting_margin"]
      .mean()
      .reset_index()
)

margin_by_discount
# Out:
#   discount_bucket  underwriting_margin
# 0            High          4752.812961
# 1             Low          5473.957701
# 2          Medium          5285.388385
# 3     No Discount          5816.846218

# %%
discounted = df[df["discount_applied"] == 1]["premium_deviation_pct"]
non_discounted = df[df["discount_applied"] == 0]["premium_deviation_pct"]

t_stat, p_value = stats.ttest_ind(
    discounted,
    non_discounted,
    equal_var=False
)

t_stat, p_value
# Out:
# (-18.53617438778054, 1.934722081642445e-72)

# %%
if p_value < 0.05:
    print("Discounts significantly affect pricing (Reject H₀)")
else:
    print("No significant pricing effect (Fail to reject H₀)")
# Out:
# Discounts significantly affect pricing (Reject H₀)

# %%
df["price_sensitivity_zone"] = pd.cut(
    df["effective_price_index"],
    bins=[0, 0.9, 1.0, 1.1, np.inf],
    labels=[
        "Highly Discounted",
        "Competitive",
        "Market Priced",
        "Overpriced"
    ]
)
df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  \
# 0          41         16600             0        16600.0  ...
# 1          23         14100             0        14100.0  ...
# 2          53         19200             0        19200.0  ...
# 3          36         13300             0        13300.0  ...
# 4          57         13100             5        12445.0  ...
#
#    underwriting_margin  premium_per_vehicle_age  discount_applied  \
# 0          8924.196385              1276.923077                 0
# 1          2989.708434              1762.500000                 0
# 2          7489.870605              3840.000000                 0
# 3          7497.973768              1108.333333                 0
# 4          6618.130912              4148.333333                 1
#
#    discount_bucket  avg_vehicle_premium premium_deviation_pct  \
# 0      No Discount         16035.203145              3.522231
# 1      No Discount         13138.717949              7.316407
# 2      No Discount         20650.765125             -7.025237
# 3      No Discount         13138.717949              1.227533
# 4              Low         13138.717949             -5.279952
#
#    risk_adjusted_discount  pricing_status  effective_price_index  \
# 0                0.000000      Profitable               1.035222
# 1                0.000000      Profitable               1.073164
# 2                0.000000      Profitable               0.929748
# 3                0.000000      Profitable               1.012275
# 4                1.666667      Profitable               0.947200
#
#   price_sensitivity_zone
# 0          Market Priced
# 1          Market Priced
# 2            Competitive
# 3          Market Priced
# 4            Competitive
#
# [5 rows x 22 columns]

# %%
zone_summary = (
    df.groupby("price_sensitivity_zone")
      .agg(
          policies=("policy_id", "count"),
          avg_margin=("underwriting_margin", "mean"),
          avg_discount=("discount_pct", "mean")
      )
      .reset_index()
)

zone_summary
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_25676\124850309.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("price_sensitivity_zone")
#   price_sensitivity_zone  policies   avg_margin  avg_discount
# 0      Highly Discounted       739  4362.246334      7.686062
# 1            Competitive       728  5394.746274      5.377747
# 2          Market Priced       823  5996.950256      3.882139
# 3             Overpriced       710  6265.111983      2.521127

# %%
discount_ineffective = df[
    (df["discount_applied"] == 1) &
    (df["effective_price_index"] > 1)
]

discount_ineffective.shape
# Out:
# (665, 22)

# %%
zone_summary.to_csv(
     "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/price_sensitivity_summary.csv",
    index=False
)
