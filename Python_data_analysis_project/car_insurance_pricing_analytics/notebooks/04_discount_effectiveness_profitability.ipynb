# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
   "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/car_insurance_pricing_features.csv"
)

df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  policy_year  \
# 0          41         16600             0        16600.0  ...         2023
# 1          23         14100             0        14100.0  ...         2023
# 2          53         19200             0        19200.0  ...         2024
# 3          36         13300             0        13300.0  ...         2024
# 4          57         13100             5        12445.0  ...         2024
#
#    underwriting_margin  premium_per_vehicle_age  discount_applied  \
# 0          8924.196385              1276.923077                 0
# 1          2989.708434              1762.500000                 0
# 2          7489.870605              3840.000000                 0
# 3          7497.973768              1108.333333                 0
# 4          6618.130912              4148.333333                 1
#
#    discount_bucket avg_vehicle_premium  premium_deviation_pct  \
# 0      No Discount        16035.203145               3.522231
# 1      No Discount        13138.717949               7.316407
# 2      No Discount        20650.765125              -7.025237
# 3      No Discount        13138.717949               1.227533
# 4              Low        13138.717949              -5.279952
#
#    risk_adjusted_discount  pricing_status effective_price_index
# 0                0.000000      Profitable              1.035222
# 1                0.000000      Profitable              1.073164
# 2                0.000000      Profitable              0.929748
# 3                0.000000      Profitable              1.012275
# 4                1.666667      Profitable              0.947200
#
# [5 rows x 21 columns]

# %%
impact_summary = (
    df.groupby("discount_applied")
      .agg(
          policies=("policy_id", "count"),
          avg_premium=("final_premium", "mean"),
          avg_margin=("underwriting_margin", "mean"),
          total_margin=("underwriting_margin", "sum")
      )
      .reset_index()
)

impact_summary["discount_applied"] = impact_summary["discount_applied"].map(
    {0: "No Discount", 1: "Discounted"}
)

impact_summary
# Out:
#   discount_applied  policies   avg_premium   avg_margin  total_margin
# 0      No Discount      1309  14700.611154  5816.846218  7.614252e+06
# 1       Discounted      1691  13202.871082  5275.306444  8.920543e+06

# %%
bucket_impact = (
    df.groupby("discount_bucket")
      .agg(
          policies=("policy_id", "count"),
          avg_discount=("discount_pct", "mean"),
          avg_margin=("underwriting_margin", "mean"),
          total_margin=("underwriting_margin", "sum")
      )
      .reset_index()
)

bucket_impact
# Out:
#   discount_bucket  policies  avg_discount   avg_margin  total_margin
# 0            High       305          15.0  4752.812961  1.449608e+06
# 1             Low       771           5.0  5473.957701  4.220421e+06
# 2          Medium       615          10.0  5285.388385  3.250514e+06
# 3     No Discount      1309           0.0  5816.846218  7.614252e+06

# %%
SAFE_DISCOUNT = 10

# %%
high_discount_loss = df[
    df["discount_pct"] > SAFE_DISCOUNT
]["underwriting_margin"].sum()

high_discount_loss
# Out:
# 1449607.9530285296

# %%
underpriced_policies = df[
    df["pricing_status"] == "Underpriced"
]

risk_exposure = underpriced_policies["underwriting_margin"].sum()

risk_exposure
# Out:
# 0.0

# %%
df["profit_flag"] = np.where(
    df["underwriting_margin"] > 0, "Profitable", "Loss"
)
df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  \
# 0          41         16600             0        16600.0  ...
# 1          23         14100             0        14100.0  ...
# 2          53         19200             0        19200.0  ...
# 3          36         13300             0        13300.0  ...
# 4          57         13100             5        12445.0  ...
#
#    underwriting_margin  premium_per_vehicle_age  discount_applied  \
# 0          8924.196385              1276.923077                 0
# 1          2989.708434              1762.500000                 0
# 2          7489.870605              3840.000000                 0
# 3          7497.973768              1108.333333                 0
# 4          6618.130912              4148.333333                 1
#
#    discount_bucket  avg_vehicle_premium premium_deviation_pct  \
# 0      No Discount         16035.203145              3.522231
# 1      No Discount         13138.717949              7.316407
# 2      No Discount         20650.765125             -7.025237
# 3      No Discount         13138.717949              1.227533
# 4              Low         13138.717949             -5.279952
#
#    risk_adjusted_discount  pricing_status  effective_price_index profit_flag
# 0                0.000000      Profitable               1.035222  Profitable
# 1                0.000000      Profitable               1.073164  Profitable
# 2                0.000000      Profitable               0.929748  Profitable
# 3                0.000000      Profitable               1.012275  Profitable
# 4                1.666667      Profitable               0.947200  Profitable
#
# [5 rows x 22 columns]

# %%
df["price_sensitivity_zone"] = pd.cut(
    df["effective_price_index"],
    bins=[0, 0.9, 1.0, 1.1, float("inf")],
    labels=[
        "Highly Discounted",
        "Competitive",
        "Market Priced",
        "Overpriced"
    ]
)
df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  \
# 0          41         16600             0        16600.0  ...
# 1          23         14100             0        14100.0  ...
# 2          53         19200             0        19200.0  ...
# 3          36         13300             0        13300.0  ...
# 4          57         13100             5        12445.0  ...
#
#    underwriting_margin  premium_per_vehicle_age  discount_applied  \
# 0          8924.196385              1276.923077                 0
# 1          2989.708434              1762.500000                 0
# 2          7489.870605              3840.000000                 0
# 3          7497.973768              1108.333333                 0
# 4          6618.130912              4148.333333                 1
#
#    discount_bucket  avg_vehicle_premium premium_deviation_pct  \
# 0      No Discount         16035.203145              3.522231
# 1      No Discount         13138.717949              7.316407
# 2      No Discount         20650.765125             -7.025237
# 3      No Discount         13138.717949              1.227533
# 4              Low         13138.717949             -5.279952
#
#    risk_adjusted_discount  pricing_status  effective_price_index  \
# 0                0.000000      Profitable               1.035222
# 1                0.000000      Profitable               1.073164
# 2                0.000000      Profitable               0.929748
# 3                0.000000      Profitable               1.012275
# 4                1.666667      Profitable               0.947200
#
#   price_sensitivity_zone
# 0          Market Priced
# 1          Market Priced
# 2            Competitive
# 3          Market Priced
# 4            Competitive
#
# [5 rows x 22 columns]

# %%
np.random.seed(42)

df["claim_cost"] = (
    df["expected_claim_cost"]
    * np.random.normal(1, 0.35, size=len(df))
)

# %%
df["underwriting_margin"] = (
    df["final_premium"] - df["claim_cost"]
)

# %%
df["profit_flag"] = np.where(
    df["underwriting_margin"] > 0,
    "Profitable",
    "Loss"
)
df.head()
# Out:
#   policy_id policy_start_date vehicle_type    policy_type region  vehicle_age  \
# 0  POL10001        2023-04-13          SUV    Third Party   West           12
# 1  POL10002        2023-11-27        Sedan    Third Party   West            7
# 2  POL10003        2024-05-06       Luxury    Third Party   West            4
# 3  POL10004        2024-07-14        Sedan    Third Party   West           11
# 4  POL10005        2024-07-16        Sedan  Comprehensive  North            2
#
#    driver_age  base_premium  discount_pct  final_premium  ...  \
# 0          41         16600             0        16600.0  ...
# 1          23         14100             0        14100.0  ...
# 2          53         19200             0        19200.0  ...
# 3          36         13300             0        13300.0  ...
# 4          57         13100             5        12445.0  ...
#
#    discount_applied  discount_bucket  avg_vehicle_premium  \
# 0                 0      No Discount         16035.203145
# 1                 0      No Discount         13138.717949
# 2                 0      No Discount         20650.765125
# 3                 0      No Discount         13138.717949
# 4                 1              Low         13138.717949
#
#    premium_deviation_pct  risk_adjusted_discount pricing_status  \
# 0               3.522231                0.000000     Profitable
# 1               7.316407                0.000000     Profitable
# 2              -7.025237                0.000000     Profitable
# 3               1.227533                0.000000     Profitable
# 4              -5.279952                1.666667     Profitable
#
#    effective_price_index  price_sensitivity_zone  profit_flag    claim_cost
# 0               1.035222           Market Priced   Profitable   9010.241717
# 1               1.073164           Market Priced   Profitable  10572.636721
# 2               0.929748             Competitive   Profitable  14364.710201
# 3               1.012275           Market Priced   Profitable   8894.856944
# 4               0.947200             Competitive   Profitable   5349.335716
#
# [5 rows x 24 columns]

# %%
elasticity_profit = (
    df.groupby("price_sensitivity_zone")
      .agg(
          policies=("policy_id", "count"),
          loss_policies=("profit_flag", lambda x: (x == "Loss").sum()),
          avg_margin=("underwriting_margin", "mean")
      )
      .reset_index()
)

elasticity_profit
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_15484\1461204291.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("price_sensitivity_zone")
#   price_sensitivity_zone  policies  loss_policies   avg_margin
# 0      Highly Discounted       739             51  4236.594060
# 1            Competitive       728             42  5323.181702
# 2          Market Priced       823             46  5938.940453
# 3             Overpriced       710             48  6184.684774

# %%
impact_summary.to_csv(
    "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/discount_impact_summary.csv",
    index=False
)

# %%
bucket_impact.to_csv(
    "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/discount_bucket_impact.csv",
    index=False
)

# %%
elasticity_profit.to_csv(
    "C:/Users/Abhi/Desktop/Python_Data_Analytics_Projects/car_insurance_pricing_analytics/data/processed/elasticity_profit_summary.csv",
    index=False
)
